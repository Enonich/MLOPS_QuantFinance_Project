# %%
# importing dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import make_pipeline
from feature_engineering import calculate_bollinger_bands, calculate_daily_return, calculate_macd, calculate_sma, average_true_range

# %%
# setting up mlflow tracking
import mlflow

# mlflow.set_tracking_uri("sqlite:///mlflow.db")
# mlflow.set_experiment("stock-pred-exp")

# %env MLFLOW_TRACKING_URI = sqlite:///mlruns.db
# Out:
# env: MLFLOW_TRACKING_URI=sqlite:///mlruns.db

# %%
mlflow.create_experiment(
   name='stock_pred_exp',
   artifact_location='testing_mlflow_artifacts',
   tags={'env': "dev", "version": "1.0.0"}
)
# Out:
# 2024/02/07 14:45:46 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2024/02/07 14:45:46 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 451aebb31d03, add metric step
# INFO  [alembic.runtime.migration] Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# INFO  [alembic.runtime.migration] Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# INFO  [alembic.runtime.migration] Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# INFO  [alembic.runtime.migration] Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# INFO  [alembic.runtime.migration] Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# INFO  [89d4b8295536_create_latest_metrics_table_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Adding registered_models and model_versions tables to database.
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# INFO  [alembic.runtime.migration] Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# INFO  [alembic.runtime.migration] Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# INFO  [alembic.runtime.migration] Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# INFO  [alembic.runtime.migration] Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# INFO  [alembic.runtime.migration] Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# INFO  [alembic.runtime.migration] Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# INFO  [alembic.runtime.migration] Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# INFO  [alembic.runtime.migration] Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# INFO  [alembic.runtime.migration] Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# INFO  [alembic.runtime.migration] Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# INFO  [alembic.runtime.migration] Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# INFO  [alembic.runtime.migration] Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# INFO  [alembic.runtime.migration] Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# INFO  [alembic.runtime.migration] Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# INFO  [alembic.runtime.migration] Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# '1'

# %%
mlflow.set_experiment(experiment_name='stock_pred_exp')
# OR

"""when running the mlflow and logging the artifacts, 
we can use this code to log to the specific experiment:

with mlflow.start_run(run_name="blah_blah", experiment_id = experiment.experiment_id) as run:


"""
# Out:
# 'when running the mlflow and logging the artifacts, \nwe can use this code to log to the specific experiment:\n\nwith mlflow.start_run(run_name="blah_blah", experiment_id = experiment.experiment_id) as run:\n\n\n'

# %%
def read_dataframe(filename):
    df = pd.read_csv(filename, index_col='Datetime')
    return df

# %%
train_data = read_dataframe('../Data/EURUSD=X_5m.csv')
test_data  = read_dataframe('../Data/AAPL_5m.csv')

# Defines Dependent and Independent Variables
y_train = train_data[['Adj Close']]
y_test = test_data[['Adj Close']]

# %% [markdown]
# ### Feature Engineering

# %%
# FEATURE ENGINEERING ON TRAIN AND TEST DATA
#Feature Engineering on train_set
atr_data = average_true_range(train_data)
macd_data = calculate_macd(train_data)
dr_data = calculate_daily_return(train_data)
bb_data = calculate_bollinger_bands(train_data)
sma_data = calculate_sma(train_data)
train_sets = sma_data


#Feature Engineering on train_set
atr_data = average_true_range(test_data)
macd_data = calculate_macd(test_data)
dr_data = calculate_daily_return(test_data)
bb_data = calculate_bollinger_bands(test_data)
sma_data = calculate_sma(test_data)
test_sets = sma_data

train_sets
# Out:
#                                Open  Volume       ATR  MACD_Line  Signal_Line
# Datetime
# 2023-03-14 00:00:00+00:00  1.072731       0       NaN   0.000000     0.000000  \
# 2023-03-14 00:05:00+00:00  1.071926       0       NaN  -0.000046    -0.000009
# 2023-03-14 00:10:00+00:00  1.071582       0       NaN  -0.000054    -0.000018
# 2023-03-14 00:15:00+00:00  1.071697       0       NaN  -0.000050    -0.000024
# 2023-03-14 00:20:00+00:00  1.071926       0       NaN  -0.000028    -0.000025
# ...                             ...     ...       ...        ...          ...
# 2023-06-05 16:05:00+01:00  1.071467       0  0.000590   0.000662     0.000701
# 2023-06-05 16:10:00+01:00  1.071237       0  0.000394   0.000625     0.000686
# 2023-06-05 16:15:00+01:00  1.071467       0  0.000361   0.000579     0.000665
# 2023-06-05 16:20:00+01:00  1.071467       0  0.000361   0.000556     0.000643
# 2023-06-05 16:25:00+01:00  1.071582       0  0.000336   0.000531     0.000620
#
#                            MACD_Histogram  Daily Return  Upper Band
# Datetime
# 2023-03-14 00:00:00+00:00        0.000000           NaN         NaN  \
# 2023-03-14 00:05:00+00:00       -0.000037     -0.053575    1.072566
# 2023-03-14 00:10:00+00:00       -0.000036      0.032154    1.072351
# 2023-03-14 00:15:00+00:00       -0.000026      0.010722    1.072308
# 2023-03-14 00:20:00+00:00       -0.000003      0.021441    1.072409
# ...                                   ...           ...         ...
# 2023-06-05 16:05:00+01:00       -0.000039     -0.010703    1.073630
# 2023-06-05 16:10:00+01:00       -0.000061      0.010704    1.073585
# 2023-06-05 16:15:00+01:00       -0.000085     -0.010703    1.073516
# 2023-06-05 16:20:00+01:00       -0.000087      0.021419    1.073396
# 2023-06-05 16:25:00+01:00       -0.000090      0.000000    1.073313
#
#                            Lower Band  Simple Moving Avg
# Datetime
# 2023-03-14 00:00:00+00:00         NaN           1.072041
# 2023-03-14 00:05:00+00:00    1.070942           1.071754
# 2023-03-14 00:10:00+00:00    1.071195           1.071773
# 2023-03-14 00:15:00+00:00    1.071315           1.071811
# 2023-03-14 00:20:00+00:00    1.071351           1.071880
# ...                               ...                ...
# 2023-06-05 16:05:00+01:00    1.067999           1.070815
# 2023-06-05 16:10:00+01:00    1.068330           1.070958
# 2023-06-05 16:15:00+01:00    1.068651           1.071084
# 2023-06-05 16:20:00+01:00    1.069057           1.071227
# 2023-06-05 16:25:00+01:00    1.069370           1.071341
#
# [16941 rows x 10 columns]

# %%
# DATA PREPROCESSING
train_dataset = pd.merge(train_sets, y_train, on='Datetime')
train_dataset = train_dataset.dropna()

test_dataset = pd.merge(test_sets, y_test, on='Datetime')
test_dataset = test_dataset.dropna()

# %%
x_train = train_dataset.drop(['Open', 'Adj Close', 'Volume'], axis=1)
y_train = train_dataset[['Adj Close']]

x_test = test_dataset.drop(['Open', 'Adj Close', 'Volume'], axis=1)
y_test = test_dataset[['Adj Close']]

# Dropping The Last Row of the x_train and the first row of the y_train  
x_train = x_train.drop(x_train.index[-1])
y_train = y_train.drop(y_train.index[0])

# Dropping The Last Row of the x_test and the first row of the y_test
x_test = x_test.drop(x_test.index[-1])
y_test = y_test.drop(y_test.index[0])

# %% [markdown]
# ### MODEL ARCH

# %%
with mlflow.start_run():
    
    mlflow.sklearn.autolog()
    
    # logging parameters
    mlflow.log_param("train-data-path", "../Data/EURUSD=X_5m.csv")
    mlflow.log_param("test-data-path", "../Data/AAPL_5m.csv")
    mlflow.set_tag("developer", "Enoch")
    
    model = LinearRegression()
    degree = 1
    linear_model = make_pipeline( StandardScaler(), model)
    linear_model.fit(x_train, y_train)
    
    mlflow.set_tag('model', 'LinearRegressor')
    # MAKE PREDICTIONS AND CHECK THE VARIANCE AND BIAS VALUES
    train_pred = linear_model.predict(x_train)
    test_pred = linear_model.predict(x_test)
    
    train_mse = mean_squared_error(y_train, train_pred, squared=False)
    test_mse = mean_squared_error(y_test, test_pred, squared=False)
    train_r2 = r2_score(y_train, train_pred)
    test_r2 = r2_score(y_test, test_pred)
    
    mlflow.log_metric("rmse", test_mse)
    mlflow.log_metric("r2", test_r2)
    
    #mlflow.log_artifact(local_path="../models/Linear_Reg.pkl", artifact_path="models_pickle")

# %%
print('train mse:', train_mse)
print('train r2:', train_r2)
print('test mse:', test_mse)
print('test r2:', test_r2)
# Out:
# train mse: 0.00035554292608154454
# train r2: 0.9991575178139349
# test mse: 0.30991165941859333
# test r2: 0.9982911037294748

# %% [markdown]
# #### Ridge Architecture

# %%
with mlflow.start_run():
    
    mlflow.sklearn.autolog()
    
    # logging parameters
    mlflow.log_param("polynomial degree", 1)
    mlflow.log_param("alpha", 0.1)
    
    degree = 1
    alpha = 0.1  # Regularization strength
    ridge_model = make_pipeline(PolynomialFeatures(degree=degree), StandardScaler(), Ridge(alpha=alpha))
    ridge_model.fit(x_train, y_train)
    
    # MAKE PREDICTIONS AND CHECK THE VARIANCE AND BIAS VALUES
    train_pred = ridge_model.predict(x_train)
    test_pred = ridge_model.predict(x_test)
    mlflow.set_tag('model', 'RidgeRegressor')
    
    train_mse = mean_squared_error(y_train, train_pred, squared=False)
    test_mse = mean_squared_error(y_test, test_pred, squared=False)
    train_r2 = r2_score(y_train, train_pred)
    test_r2 = r2_score(y_test, test_pred)
    
    mlflow.log_metric("rmse", test_mse)
    mlflow.log_metric("r2", test_r2)

# %%
print('train mse:', train_mse)
print('train r2:', train_r2)
print('test mse:', test_mse)
print('test r2:', test_r2)
# Out:
# train mse: 0.0003555427720491671
# train r2: 0.9991575185439143
# test mse: 0.30955395242571454
# test r2: 0.9982950463456918

# %% [markdown]
# ### Lasso Architecture

# %%
with mlflow.start_run():
    
    mlflow.sklearn.autolog()
    
    # logging parameters
    #mlflow.log_param("train-data-path", "../Data/EURUSD=X_5m.csv")
    #mlflow.log_param("test-data-path", "../Data/AAPL_5m.csv")
    
    
    model = LinearRegression()
    degree = 1
    alpha = 0.00001  # Regularization strength
    lasso_model = make_pipeline(PolynomialFeatures(degree=degree), StandardScaler(), Lasso(alpha=alpha))
    lasso_model.fit(x_train, y_train)
    
    mlflow.set_tag('model', 'LassoRegressor')
    # MAKE PREDICTIONS AND CHECK THE VARIANCE AND BIAS VALUES
    train_pred = lasso_model.predict(x_train)
    test_pred = lasso_model.predict(x_test)
    
    train_mse = mean_squared_error(y_train, train_pred, squared=False)
    test_mse = mean_squared_error(y_test, test_pred, squared=False)
    train_r2 = r2_score(y_train, train_pred)
    test_r2 = r2_score(y_test, test_pred)
    
    mlflow.log_metric("rmse", test_mse)
    mlflow.log_metric("r2", test_r2)

# %%
print('train mse:', train_mse)
print('train r2:', train_r2)
print('test mse:', test_mse)
print('test r2:', test_r2)
# Out:
# train mse: 0.0003560888486147838
# train r2: 0.999154928629463
# test mse: 0.35106833861197767
# test r2: 0.9978070779264776

# %% [markdown]
# ### Stochastic Gradient Descent Regressor with Ridge Regularization

# %%
from sklearn.linear_model import SGDRegressor
with mlflow.start_run():
    
    mlflow.sklearn.autolog()
     # logging parameters
    #mlflow.log_param("train-data-path", "../Data/EURUSD=X_5m.csv")
    #mlflow.log_param("test-data-path", "../Data/AAPL_5m.csv")

    degree = 1      # 1
    alpha = 0.002  # Regularization strength 0.0001
    max_iter = 115  # 120

    SGD_model = make_pipeline(PolynomialFeatures(degree=degree), StandardScaler(), SGDRegressor(alpha=alpha, max_iter=max_iter))
    SGD_model.fit(x_train, y_train)
    mlflow.set_tag('model', 'SGDRegressor')
    
    
    # MAKE PREDICTIONS AND CHECK THE VARIANCE AND BIAS VALUES
    train_pred = SGD_model.predict(x_train)
    test_pred = SGD_model.predict(x_test)
    
    train_mse = mean_squared_error(y_train, train_pred, squared=False)
    test_mse = mean_squared_error(y_test, test_pred, squared=False)
    train_r2 = r2_score(y_train, train_pred)
    test_r2 = r2_score(y_test, test_pred)
    
    mlflow.log_metric("rmse", test_mse)
    mlflow.log_metric("r2", test_r2)
# Out:
# c:\Users\AIDOO K. ENOCH\.conda\envs\model_orch\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print('train mse:', train_mse)
print('train r2:', train_r2)
print('test mse:', test_mse)
print('test r2:', test_r2)
# Out:
# train mse: 0.00035738209390664787
# train r2: 0.9991487792139596
# test mse: 0.31108878493922765
# test r2: 0.9982780974058042

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope


train = xgb.DMatrix(x_train, label=y_train)
valid = xgb.DMatrix(x_test, label=y_test)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_test, y_pred, squared=False)
        r2   = r2_score(y_test, y_pred)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("r2-score", r2)

    return {'loss': rmse, 'r2-score': r2, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [14:57:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:165.84187
# [1]	validation-rmse:165.78875
# [2]	validation-rmse:165.74063
# [3]	validation-rmse:165.69743
# [4]	validation-rmse:165.65837
# [5]	validation-rmse:165.62338
# [6]	validation-rmse:165.59167
# [7]	validation-rmse:165.56283
# [8]	validation-rmse:165.53713
# [9]	validation-rmse:165.51361
# [10]	validation-rmse:165.49273
# [11]	validation-rmse:165.47354
# [12]	validation-rmse:165.45649
# [13]	validation-rmse:165.44096
# [14]	validation-rmse:165.42685
# [15]	validation-rmse:165.41432
# [16]	validation-rmse:165.40294
# [17]	validation-rmse:165.39276
# [18]	validation-rmse:165.38333
# [19]	validation-rmse:165.37506
# [20]	validation-rmse:165.36757
# [21]	validation-rmse:165.36058
# [22]	validation-rmse:165.35447
# [23]	validation-rmse:165.34904
# [24]	validation-rmse:165.34392
# [25]	validation-rmse:165.33943
# [26]	validation-rmse:165.33542
# [27]	validation-rmse:165.33156
# [28]	validation-rmse:165.32824
# [29]	validation-rmse:165.32507
# [30]	validation-rmse:165.32232
# [31]	validation-rmse:165.31995
# [32]	validation-rmse:165.31760
# [33]	validation-rmse:165.31562
# [34]	validation-rmse:165.31379
# [35]	validation-rmse:165.31220
# [36]	validation-rmse:165.31057
# [37]	validation-rmse:165.30909
# [38]	validation-rmse:165.30786
# [39]	validation-rmse:165.30679
# [40]	validation-rmse:165.30571
# [41]	validation-rmse:165.30485
# [42]	validation-rmse:165.30408
# [43]	validation-rmse:165.30323
# [44]	validation-rmse:165.30284
# [45]	validation-rmse:165.30230
# [46]	validation-rmse:165.30197
# [47]	validation-rmse:165.30168
# [48]	validation-rmse:165.30143
# [49]	validation-rmse:165.30106
# [50]	validation-rmse:165.30081
# [51]	validation-rmse:165.30056
# [52]	validation-rmse:165.30031
# [53]	validation-rmse:165.30031
# [54]	validation-rmse:165.30013
# [55]	validation-rmse:165.29996
# [56]	validation-rmse:165.29985
# [57]	validation-rmse:165.29971
# [58]	validation-rmse:165.29971
# [59]	validation-rmse:165.29957
# [60]	validation-rmse:165.29942
# [61]	validation-rmse:165.29937
# [62]	validation-rmse:165.29929
# [63]	validation-rmse:165.29915
# [64]	validation-rmse:165.29915
# [65]	validation-rmse:165.29912
# [66]	validation-rmse:165.29907
# [67]	validation-rmse:165.29893
# [68]	validation-rmse:165.29890
# [69]	validation-rmse:165.29880
# [70]	validation-rmse:165.29875
# [71]	validation-rmse:165.29868
# [72]	validation-rmse:165.29865
# [73]	validation-rmse:165.29863
# [74]	validation-rmse:165.29861
# [75]	validation-rmse:165.29861
# [76]	validation-rmse:165.29855
# [77]	validation-rmse:165.29850
# [78]	validation-rmse:165.29847
# [79]	validation-rmse:165.29845
# [80]	validation-rmse:165.29843
# [81]	validation-rmse:165.29839
# [82]	validation-rmse:165.29835
# [83]	validation-rmse:165.29834
# [84]	validation-rmse:165.29833
# [85]	validation-rmse:165.29831
# [86]	validation-rmse:165.29829
# [87]	validation-rmse:165.29828
# [88]	validation-rmse:165.29825
# [89]	validation-rmse:165.29822
# [90]	validation-rmse:165.29820
# [91]	validation-rmse:165.29819
# [92]	validation-rmse:165.29818
# [93]	validation-rmse:165.29817
# [94]	validation-rmse:165.29814
# [95]	validation-rmse:165.29814
# [96]	validation-rmse:165.29812
# [97]	validation-rmse:165.29810
# [98]	validation-rmse:165.29809
# [99]	validation-rmse:165.29808
# [100]	validation-rmse:165.29808
# [101]	validation-rmse:165.29808
# [102]	validation-rmse:165.29807
# [103]	validation-rmse:165.29806
# [104]	validation-rmse:165.29804
# [105]	validation-rmse:165.29803
# [106]	validation-rmse:165.29802
# [107]	validation-rmse:165.29801
# [108]	validation-rmse:165.29801
# [109]	validation-rmse:165.29799
# [110]	validation-rmse:165.29798
# [111]	validation-rmse:165.29798
# [112]	validation-rmse:165.29797
# [113]	validation-rmse:165.29796
# [114]	validation-rmse:165.29795
# [115]	validation-rmse:165.29794
# [116]	validation-rmse:165.29793
# [117]	validation-rmse:165.29792
# [118]	validation-rmse:165.29792
# [119]	validation-rmse:165.29792
# [120]	validation-rmse:165.29791
# [121]	validation-rmse:165.29790
# [122]	validation-rmse:165.29790
# [123]	validation-rmse:165.29789
# [124]	validation-rmse:165.29789
# [125]	validation-rmse:165.29789
# [126]	validation-rmse:165.29788
# [127]	validation-rmse:165.29787
# [128]	validation-rmse:165.29786
# [129]	validation-rmse:165.29786
# [130]	validation-rmse:165.29786
# [131]	validation-rmse:165.29785
# [132]	validation-rmse:165.29785
# [133]	validation-rmse:165.29785
# [134]	validation-rmse:165.29785
# [135]	validation-rmse:165.29784
# [136]	validation-rmse:165.29783
# [137]	validation-rmse:165.29783
# [138]	validation-rmse:165.29782
# [139]	validation-rmse:165.29782
# [140]	validation-rmse:165.29782
# [141]	validation-rmse:165.29781
# [142]	validation-rmse:165.29781
# [143]	validation-rmse:165.29781
# [144]	validation-rmse:165.29781
# [145]	validation-rmse:165.29780
# [146]	validation-rmse:165.29780
# [147]	validation-rmse:165.29780
# [148]	validation-rmse:165.29780
# [149]	validation-rmse:165.29780
# [150]	validation-rmse:165.29780
# [151]	validation-rmse:165.29780
# [152]	validation-rmse:165.29780
# [153]	validation-rmse:165.29780
# [154]	validation-rmse:165.29780
# [155]	validation-rmse:165.29780
# [156]	validation-rmse:165.29780
# [157]	validation-rmse:165.29780
# [158]	validation-rmse:165.29780
# [159]	validation-rmse:165.29780
# [160]	validation-rmse:165.29780
# [161]	validation-rmse:165.29780
# [162]	validation-rmse:165.29780
# [163]	validation-rmse:165.29780
# [164]	validation-rmse:165.29780
# [165]	validation-rmse:165.29780
# [166]	validation-rmse:165.29780
# [167]	validation-rmse:165.29780
# [168]	validation-rmse:165.29780
# [169]	validation-rmse:165.29780
# [170]	validation-rmse:165.29780
# [171]	validation-rmse:165.29780
# [172]	validation-rmse:165.29780
# [173]	validation-rmse:165.29780
# [174]	validation-rmse:165.29780
# [175]	validation-rmse:165.29780
# [176]	validation-rmse:165.29780
# [177]	validation-rmse:165.29780
# [178]	validation-rmse:165.29780
# [179]	validation-rmse:165.29780
# [180]	validation-rmse:165.29780
# [181]	validation-rmse:165.29780
# [182]	validation-rmse:165.29780
# [183]	validation-rmse:165.29780
# [184]	validation-rmse:165.29780
# [185]	validation-rmse:165.29780
# [186]	validation-rmse:165.29780
# [187]	validation-rmse:165.29780
# [188]	validation-rmse:165.29780
# [189]	validation-rmse:165.29780
# [190]	validation-rmse:165.29780
# [191]	validation-rmse:165.29780
# [192]	validation-rmse:165.29780
# [193]	validation-rmse:165.29780
# [194]	validation-rmse:165.29780
# [195]	validation-rmse:165.29780
# [196]	validation-rmse:165.29780
# [197]	validation-rmse:165.29780
# [14:57:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:165.67052
# [1]	validation-rmse:165.52777
# [2]	validation-rmse:165.43919
# [3]	validation-rmse:165.38519
# [4]	validation-rmse:165.35104
# [5]	validation-rmse:165.33048
# [6]	validation-rmse:165.31706
# [7]	validation-rmse:165.30911
# [8]	validation-rmse:165.30423
# [9]	validation-rmse:165.30108
# [10]	validation-rmse:165.29857
# [11]	validation-rmse:165.29701
# [12]	validation-rmse:165.29630
# [13]	validation-rmse:165.29592
# [14]	validation-rmse:165.29534
# [15]	validation-rmse:165.29509
# [16]	validation-rmse:165.29485
# [17]	validation-rmse:165.29476
# [18]	validation-rmse:165.29464
# [19]	validation-rmse:165.29458
# [20]	validation-rmse:165.29443
# [21]	validation-rmse:165.29439
# [22]	validation-rmse:165.29438
# [23]	validation-rmse:165.29428
# [24]	validation-rmse:165.29425
# [25]	validation-rmse:165.29424
# [26]	validation-rmse:165.29421
# [27]	validation-rmse:165.29421
# [28]	validation-rmse:165.29416
# [29]	validation-rmse:165.29417
# [30]	validation-rmse:165.29416
# [31]	validation-rmse:165.29415
# [32]	validation-rmse:165.29412
# [33]	validation-rmse:165.29412
# [34]	validation-rmse:165.29412
# [35]	validation-rmse:165.29412
# [36]	validation-rmse:165.29412
# [37]	validation-rmse:165.29412
# [38]	validation-rmse:165.29412
# [39]	validation-rmse:165.29412
# [40]	validation-rmse:165.29412
# [41]	validation-rmse:165.29412
# [42]	validation-rmse:165.29412
# [43]	validation-rmse:165.29412
# [44]	validation-rmse:165.29412
# [45]	validation-rmse:165.29412
# [46]	validation-rmse:165.29412
# [47]	validation-rmse:165.29412
# [48]	validation-rmse:165.29412
# [49]	validation-rmse:165.29412
# [50]	validation-rmse:165.29412
# [51]	validation-rmse:165.29412
# [52]	validation-rmse:165.29412
# [53]	validation-rmse:165.29412
# [54]	validation-rmse:165.29412
# [55]	validation-rmse:165.29412
# [56]	validation-rmse:165.29412
# [57]	validation-rmse:165.29412
# [58]	validation-rmse:165.29412
# [59]	validation-rmse:165.29412
# [60]	validation-rmse:165.29412
# [61]	validation-rmse:165.29412
# [62]	validation-rmse:165.29412
# [63]	validation-rmse:165.29412
# [64]	validation-rmse:165.29412
# [65]	validation-rmse:165.29412
# [66]	validation-rmse:165.29412
# [67]	validation-rmse:165.29412
# [68]	validation-rmse:165.29412
# [69]	validation-rmse:165.29412
# [70]	validation-rmse:165.29412
# [71]	validation-rmse:165.29412
# [72]	validation-rmse:165.29412
# [73]	validation-rmse:165.29412
# [74]	validation-rmse:165.29412
# [75]	validation-rmse:165.29412
# [76]	validation-rmse:165.29412
# [77]	validation-rmse:165.29412
# [78]	validation-rmse:165.29412
# [79]	validation-rmse:165.29412
# [80]	validation-rmse:165.29412
# [81]	validation-rmse:165.29412
# [82]	validation-rmse:165.29412
# [14:57:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:165.70494
# [1]	validation-rmse:165.57236
# [2]	validation-rmse:165.48267
# [3]	validation-rmse:165.42180
# [4]	validation-rmse:165.38092
# [5]	validation-rmse:165.35305
# [6]	validation-rmse:165.33484
# [7]	validation-rmse:165.32243
# [8]	validation-rmse:165.31379
# [9]	validation-rmse:165.30813
# [10]	validation-rmse:165.30384
# [11]	validation-rmse:165.30057
# [12]	validation-rmse:165.29964
# [13]	validation-rmse:165.29851
# [14]	validation-rmse:165.29789
# [15]	validation-rmse:165.29767
# [16]	validation-rmse:165.29718
# [17]	validation-rmse:165.29691
# [18]	validation-rmse:165.29673
# [19]	validation-rmse:165.29663
# [20]	validation-rmse:165.29657
# [21]	validation-rmse:165.29656
# [22]	validation-rmse:165.29644
# [23]	validation-rmse:165.29643
# [24]	validation-rmse:165.29635
# [25]	validation-rmse:165.29633
# [26]	validation-rmse:165.29630
# [27]	validation-rmse:165.29627
# [28]	validation-rmse:165.29621
# [29]	validation-rmse:165.29619
# [30]	validation-rmse:165.29618
# [31]	validation-rmse:165.29614
# [32]	validation-rmse:165.29613
# [33]	validation-rmse:165.29613
# [34]	validation-rmse:165.29612
# [35]	validation-rmse:165.29612
# [36]	validation-rmse:165.29612
# [37]	validation-rmse:165.29612
# [38]	validation-rmse:165.29612
# [39]	validation-rmse:165.29612
# [40]	validation-rmse:165.29612
# [41]	validation-rmse:165.29612
# [42]	validation-rmse:165.29612
# [43]	validation-rmse:165.29612
# [44]	validation-rmse:165.29612
# [45]	validation-rmse:165.29612
# [46]	validation-rmse:165.29612
# [47]	validation-rmse:165.29612
# [48]	validation-rmse:165.29612
# [49]	validation-rmse:165.29612
# [50]	validation-rmse:165.29612
# [51]	validation-rmse:165.29612
# [52]	validation-rmse:165.29612
# [53]	validation-rmse:165.29612
# [54]	validation-rmse:165.29612
# [55]	validation-rmse:165.29612
# [56]	validation-rmse:165.29612
# [57]	validation-rmse:165.29612
# [58]	validation-rmse:165.29612
# [59]	validation-rmse:165.29612
# [60]	validation-rmse:165.29612
# [61]	validation-rmse:165.29612
# [62]	validation-rmse:165.29612
# [63]	validation-rmse:165.29612
# [64]	validation-rmse:165.29612
# [65]	validation-rmse:165.29612
# [66]	validation-rmse:165.29612
# [67]	validation-rmse:165.29612
# [68]	validation-rmse:165.29612
# [69]	validation-rmse:165.29612
# [70]	validation-rmse:165.29612
# [71]	validation-rmse:165.29612
# [72]	validation-rmse:165.29612
# [73]	validation-rmse:165.29612
# [74]	validation-rmse:165.29612
# [75]	validation-rmse:165.29612
# [76]	validation-rmse:165.29612
# [77]	validation-rmse:165.29612
# [78]	validation-rmse:165.29612
# [79]	validation-rmse:165.29612
# [80]	validation-rmse:165.29612
# [81]	validation-rmse:165.29612
# [82]	validation-rmse:165.29612
# [83]	validation-rmse:165.29612
# [84]	validation-rmse:165.29612
# [85]	validation-rmse:165.29612
# [86]	validation-rmse:165.29612
# [87]	validation-rmse:165.29612
# [88]	validation-rmse:165.29612
# [89]	validation-rmse:165.29612
# [14:57:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:165.86859
# [1]	validation-rmse:165.83811
# [2]	validation-rmse:165.80922
# [3]	validation-rmse:165.78181
# [4]	validation-rmse:165.75599
# [5]	validation-rmse:165.73154
# [6]	validation-rmse:165.70826
# [7]	validation-rmse:165.68625
# [8]	validation-rmse:165.66554
# [9]	validation-rmse:165.64601
# [10]	validation-rmse:165.62745
# [11]	validation-rmse:165.60995
# [12]	validation-rmse:165.59327
# [13]	validation-rmse:165.57760
# [14]	validation-rmse:165.56272
# [15]	validation-rmse:165.54849
# [16]	validation-rmse:165.53507
# [17]	validation-rmse:165.52250
# [18]	validation-rmse:165.51042
# [19]	validation-rmse:165.49916
# [20]	validation-rmse:165.48834
# [21]	validation-rmse:165.47828
# [22]	validation-rmse:165.46864
# [23]	validation-rmse:165.45959
# [24]	validation-rmse:165.45087
# [25]	validation-rmse:165.44276
# [26]	validation-rmse:165.43492
# [27]	validation-rmse:165.42755
# [28]	validation-rmse:165.42066
# [29]	validation-rmse:165.41400
# [30]	validation-rmse:165.40784
# [31]	validation-rmse:165.40189
# [32]	validation-rmse:165.39636
# [33]	validation-rmse:165.39107
# [34]	validation-rmse:165.38615
# [35]	validation-rmse:165.38133
# [36]	validation-rmse:165.37689
# [37]	validation-rmse:165.37256
# [38]	validation-rmse:165.36859
# [39]	validation-rmse:165.36487
# [40]	validation-rmse:165.36130
# [41]	validation-rmse:165.35781
# [42]	validation-rmse:165.35461
# [43]	validation-rmse:165.35150
# [44]	validation-rmse:165.34863
# [45]	validation-rmse:165.34595
# [46]	validation-rmse:165.34337
# [47]	validation-rmse:165.34083
# [48]	validation-rmse:165.33854
# [49]	validation-rmse:165.33635
# [50]	validation-rmse:165.33418
# [51]	validation-rmse:165.33223
# [52]	validation-rmse:165.33028
# [53]	validation-rmse:165.32856
# [54]	validation-rmse:165.32688
# [55]	validation-rmse:165.32522
# [56]	validation-rmse:165.32374
# [57]	validation-rmse:165.32232
# [58]	validation-rmse:165.32089
# [59]	validation-rmse:165.31965
# [60]	validation-rmse:165.31842
# [61]	validation-rmse:165.31720
# [62]	validation-rmse:165.31612
# [63]	validation-rmse:165.31501
# [64]	validation-rmse:165.31399
# [65]	validation-rmse:165.31309
# [66]	validation-rmse:165.31220
# [67]	validation-rmse:165.31130
# [68]	validation-rmse:165.31053
# [69]	validation-rmse:165.30972
# [70]	validation-rmse:165.30905
# [71]	validation-rmse:165.30836
# [72]	validation-rmse:165.30769
# [73]	validation-rmse:165.30713
# [74]	validation-rmse:165.30655
# [75]	validation-rmse:165.30603
# [76]	validation-rmse:165.30554
# [77]	validation-rmse:165.30500
# [78]	validation-rmse:165.30455
# [79]	validation-rmse:165.30406
# [80]	validation-rmse:165.30367
# [81]	validation-rmse:165.30331
# [82]	validation-rmse:165.30295
# [83]	validation-rmse:165.30254
# [84]	validation-rmse:165.30224
# [85]	validation-rmse:165.30193
# [86]	validation-rmse:165.30175
# [87]	validation-rmse:165.30147
# [88]	validation-rmse:165.30122
# [89]	validation-rmse:165.30107
# [90]	validation-rmse:165.30093
# [91]	validation-rmse:165.30072
# [92]	validation-rmse:165.30058
# [93]	validation-rmse:165.30042
# [94]	validation-rmse:165.30030
# [95]	validation-rmse:165.30015
# [96]	validation-rmse:165.30002
# [97]	validation-rmse:165.29990
# [98]	validation-rmse:165.29971
# [99]	validation-rmse:165.29958
# [100]	validation-rmse:165.29940
# [101]	validation-rmse:165.29923
# [102]	validation-rmse:165.29920
# [103]	validation-rmse:165.29912
# [104]	validation-rmse:165.29898
# [105]	validation-rmse:165.29891
# [106]	validation-rmse:165.29884
# [107]	validation-rmse:165.29878
# [108]	validation-rmse:165.29865
# [109]	validation-rmse:165.29861
# [110]	validation-rmse:165.29855
# [111]	validation-rmse:165.29844
# [112]	validation-rmse:165.29838
# [113]	validation-rmse:165.29832
# [114]	validation-rmse:165.29830
# [115]	validation-rmse:165.29824
# [116]	validation-rmse:165.29820
# [117]	validation-rmse:165.29816
# [118]	validation-rmse:165.29812
# [119]	validation-rmse:165.29805
# [120]	validation-rmse:165.29800
# [121]	validation-rmse:165.29797
# [122]	validation-rmse:165.29795
# [123]	validation-rmse:165.29790
# [124]	validation-rmse:165.29786
# [125]	validation-rmse:165.29783
# [126]	validation-rmse:165.29779
# [127]	validation-rmse:165.29776
# [128]	validation-rmse:165.29771
# [129]	validation-rmse:165.29770
# [130]	validation-rmse:165.29767
# [131]	validation-rmse:165.29765
# [132]	validation-rmse:165.29762
# [133]	validation-rmse:165.29760
# [134]	validation-rmse:165.29757
# [135]	validation-rmse:165.29755
# [136]	validation-rmse:165.29754
# [137]	validation-rmse:165.29751
# [138]	validation-rmse:165.29749
# [139]	validation-rmse:165.29746
# [140]	validation-rmse:165.29743
# [141]	validation-rmse:165.29742
# [142]	validation-rmse:165.29738
# [143]	validation-rmse:165.29737
# [144]	validation-rmse:165.29737
# [145]	validation-rmse:165.29734
# [146]	validation-rmse:165.29734
# [147]	validation-rmse:165.29732
# [148]	validation-rmse:165.29729
# [149]	validation-rmse:165.29727
# [150]	validation-rmse:165.29726
# [151]	validation-rmse:165.29723
# [152]	validation-rmse:165.29721
# [153]	validation-rmse:165.29720
# [154]	validation-rmse:165.29719
# [155]	validation-rmse:165.29719
# [156]	validation-rmse:165.29716
# [157]	validation-rmse:165.29713
# [158]	validation-rmse:165.29712
# [159]	validation-rmse:165.29711
# [160]	validation-rmse:165.29709
# [161]	validation-rmse:165.29708
# [162]	validation-rmse:165.29707
# [163]	validation-rmse:165.29706
# [164]	validation-rmse:165.29705
# [165]	validation-rmse:165.29704
# [166]	validation-rmse:165.29703
# [167]	validation-rmse:165.29702
# [168]	validation-rmse:165.29701
# [169]	validation-rmse:165.29700
# [170]	validation-rmse:165.29699
# [171]	validation-rmse:165.29699
# [172]	validation-rmse:165.29698
# [173]	validation-rmse:165.29697
# [174]	validation-rmse:165.29696
# [175]	validation-rmse:165.29696
# [176]	validation-rmse:165.29696
# [177]	validation-rmse:165.29695
# [178]	validation-rmse:165.29694
# [179]	validation-rmse:165.29692
# [180]	validation-rmse:165.29692
# [181]	validation-rmse:165.29692
# [182]	validation-rmse:165.29691
# [183]	validation-rmse:165.29690
# [184]	validation-rmse:165.29690
# [185]	validation-rmse:165.29688
# [186]	validation-rmse:165.29688
# [187]	validation-rmse:165.29687
# [188]	validation-rmse:165.29686
# [189]	validation-rmse:165.29686
# [190]	validation-rmse:165.29686
# [191]	validation-rmse:165.29685
# [192]	validation-rmse:165.29684
# [193]	validation-rmse:165.29683
# [194]	validation-rmse:165.29683
# [195]	validation-rmse:165.29683
# [196]	validation-rmse:165.29682
# [197]	validation-rmse:165.29681
# [198]	validation-rmse:165.29681
# [199]	validation-rmse:165.29681
# [200]	validation-rmse:165.29681
# [201]	validation-rmse:165.29680
# [202]	validation-rmse:165.29680
# [203]	validation-rmse:165.29679
# [204]	validation-rmse:165.29679
# [205]	validation-rmse:165.29679
# [206]	validation-rmse:165.29678
# [207]	validation-rmse:165.29677
# [208]	validation-rmse:165.29677
# [209]	validation-rmse:165.29677
# [210]	validation-rmse:165.29677
# [211]	validation-rmse:165.29676
# [212]	validation-rmse:165.29675
# [213]	validation-rmse:165.29675
# [214]	validation-rmse:165.29674
# [215]	validation-rmse:165.29674
# [216]	validation-rmse:165.29674
# [217]	validation-rmse:165.29673
# [218]	validation-rmse:165.29673
# [219]	validation-rmse:165.29673
# [220]	validation-rmse:165.29673
# [221]	validation-rmse:165.29672
# [222]	validation-rmse:165.29672
# [223]	validation-rmse:165.29672
# [224]	validation-rmse:165.29671
# [225]	validation-rmse:165.29670
# [226]	validation-rmse:165.29670
# [227]	validation-rmse:165.29670
# [228]	validation-rmse:165.29670
# [229]	validation-rmse:165.29669
# [230]	validation-rmse:165.29669
# [231]	validation-rmse:165.29669
# [232]	validation-rmse:165.29669
# [233]	validation-rmse:165.29668
# [234]	validation-rmse:165.29668
# [235]	validation-rmse:165.29667
# [236]	validation-rmse:165.29667
# [237]	validation-rmse:165.29667
# [238]	validation-rmse:165.29667
# [239]	validation-rmse:165.29667
# [240]	validation-rmse:165.29667
# [241]	validation-rmse:165.29666
# [242]	validation-rmse:165.29666
# [243]	validation-rmse:165.29666
# [244]	validation-rmse:165.29666
# [245]	validation-rmse:165.29666
# [246]	validation-rmse:165.29666
# [247]	validation-rmse:165.29666
# [248]	validation-rmse:165.29665
# [249]	validation-rmse:165.29665
# [250]	validation-rmse:165.29665
# [251]	validation-rmse:165.29665
# [252]	validation-rmse:165.29664
# [253]	validation-rmse:165.29664
# [254]	validation-rmse:165.29664
# [255]	validation-rmse:165.29664
# [256]	validation-rmse:165.29663
# [257]	validation-rmse:165.29663
# [258]	validation-rmse:165.29663
# [259]	validation-rmse:165.29663
# [260]	validation-rmse:165.29663
# [261]	validation-rmse:165.29663
# [262]	validation-rmse:165.29662
# [263]	validation-rmse:165.29662
# [264]	validation-rmse:165.29662
# [265]	validation-rmse:165.29662
# [266]	validation-rmse:165.29662
# [267]	validation-rmse:165.29662
# [268]	validation-rmse:165.29662
# [269]	validation-rmse:165.29661
# [270]	validation-rmse:165.29661
# [271]	validation-rmse:165.29661
# [272]	validation-rmse:165.29661
# [273]	validation-rmse:165.29661
# [274]	validation-rmse:165.29661
# [275]	validation-rmse:165.29661
# [276]	validation-rmse:165.29661
# [277]	validation-rmse:165.29661
# ...
# [33]	validation-rmse:165.34183
# [34]	validation-rmse:165.33847
# [35]	validation-rmse:165.33537
# [36]	validation-rmse:165.33233
# [37]	validation-rmse:165.32964
# [38]	validation-rmse:165.32716
# [39]	validation-rmse:165.32472
# [40]	validation-rmse:165.32258
# [41]	validation-rmse:165.32059
# [42]	validation-rmse:165.31876
# [43]	validation-rmse:165.31707
# [44]	validation-rmse:165.31544
# [45]	validation-rmse:165.31399
# [46]	validation-rmse:165.31262
# [47]	validation-rmse:165.31131
# [48]	validation-rmse:165.31009
# [49]	validation-rmse:165.30898
# [50]	validation-rmse:165.30797
# [51]	validation-rmse:165.30701
# [52]	validation-rmse:165.30612
# [53]	validation-rmse:165.30530
# [54]	validation-rmse:165.30456
# [55]	validation-rmse:165.30380
# [56]	validation-rmse:165.30315
# [57]	validation-rmse:165.30244
# [58]	validation-rmse:165.30190
# [59]	validation-rmse:165.30129
# [60]	validation-rmse:165.30080
# [61]	validation-rmse:165.30036
# [62]	validation-rmse:165.29997
# [63]	validation-rmse:165.29958
# [64]	validation-rmse:165.29922
# [65]	validation-rmse:165.29888
# [66]	validation-rmse:165.29853
# [67]	validation-rmse:165.29822
# [68]	validation-rmse:165.29799
# [69]	validation-rmse:165.29775
# [70]	validation-rmse:165.29748
# [71]	validation-rmse:165.29722
# [72]	validation-rmse:165.29705
# [73]	validation-rmse:165.29688
# [74]	validation-rmse:165.29671
# [75]	validation-rmse:165.29652
# [76]	validation-rmse:165.29637
# [77]	validation-rmse:165.29622
# [78]	validation-rmse:165.29608
# [79]	validation-rmse:165.29597
# [80]	validation-rmse:165.29584
# [81]	validation-rmse:165.29575
# [82]	validation-rmse:165.29568
# [83]	validation-rmse:165.29560
# [84]	validation-rmse:165.29551
# [85]	validation-rmse:165.29545
# [86]	validation-rmse:165.29535
# [87]	validation-rmse:165.29528
# [88]	validation-rmse:165.29523
# [89]	validation-rmse:165.29515
# [90]	validation-rmse:165.29508
# [91]	validation-rmse:165.29503
# [92]	validation-rmse:165.29500
# [93]	validation-rmse:165.29494
# [94]	validation-rmse:165.29488
# [95]	validation-rmse:165.29484
# [96]	validation-rmse:165.29479
# [97]	validation-rmse:165.29474
# [98]	validation-rmse:165.29471
# [99]	validation-rmse:165.29468
# [100]	validation-rmse:165.29463
# [101]	validation-rmse:165.29461
# [102]	validation-rmse:165.29458
# [103]	validation-rmse:165.29455
# [104]	validation-rmse:165.29453
# [105]	validation-rmse:165.29451
# [106]	validation-rmse:165.29448
# [107]	validation-rmse:165.29446
# [108]	validation-rmse:165.29444
# [109]	validation-rmse:165.29442
# [110]	validation-rmse:165.29440
# [111]	validation-rmse:165.29438
# [112]	validation-rmse:165.29437
# [113]	validation-rmse:165.29437
# [114]	validation-rmse:165.29435
# [115]	validation-rmse:165.29434
# [116]	validation-rmse:165.29433
# [117]	validation-rmse:165.29430
# [118]	validation-rmse:165.29429
# [119]	validation-rmse:165.29428
# [120]	validation-rmse:165.29426
# [121]	validation-rmse:165.29425
# [122]	validation-rmse:165.29424
# [123]	validation-rmse:165.29423
# [124]	validation-rmse:165.29422
# [125]	validation-rmse:165.29421
# [126]	validation-rmse:165.29419
# [127]	validation-rmse:165.29419
# [128]	validation-rmse:165.29418
# [129]	validation-rmse:165.29416
# [130]	validation-rmse:165.29416
# [131]	validation-rmse:165.29415
# [132]	validation-rmse:165.29414
# [133]	validation-rmse:165.29413
# [134]	validation-rmse:165.29412
# [135]	validation-rmse:165.29412
# [136]	validation-rmse:165.29411
# [137]	validation-rmse:165.29410
# [138]	validation-rmse:165.29410
# [139]	validation-rmse:165.29410
# [140]	validation-rmse:165.29409
# [141]	validation-rmse:165.29408
# [142]	validation-rmse:165.29408
# [143]	validation-rmse:165.29407
# [144]	validation-rmse:165.29407
# [145]	validation-rmse:165.29406
# [146]	validation-rmse:165.29406
# [147]	validation-rmse:165.29406
# [148]	validation-rmse:165.29405
# [149]	validation-rmse:165.29405
# [150]	validation-rmse:165.29405
# [151]	validation-rmse:165.29405
# [152]	validation-rmse:165.29405
# [153]	validation-rmse:165.29405
# [154]	validation-rmse:165.29404
# [155]	validation-rmse:165.29404
# [156]	validation-rmse:165.29404
# [157]	validation-rmse:165.29404
# [158]	validation-rmse:165.29404
# [159]	validation-rmse:165.29403
# [160]	validation-rmse:165.29403
# [161]	validation-rmse:165.29403
# [162]	validation-rmse:165.29403
# [163]	validation-rmse:165.29403
# [164]	validation-rmse:165.29403
# [165]	validation-rmse:165.29403
# [166]	validation-rmse:165.29403
# [167]	validation-rmse:165.29403
# [168]	validation-rmse:165.29403
# [169]	validation-rmse:165.29403
# [170]	validation-rmse:165.29403
# [171]	validation-rmse:165.29403
# [172]	validation-rmse:165.29403
# [173]	validation-rmse:165.29403
# [174]	validation-rmse:165.29403
# [175]	validation-rmse:165.29403
# [176]	validation-rmse:165.29403
# [177]	validation-rmse:165.29403
# [178]	validation-rmse:165.29403
# [179]	validation-rmse:165.29403
# [180]	validation-rmse:165.29403
# [181]	validation-rmse:165.29403
# [182]	validation-rmse:165.29403
# [183]	validation-rmse:165.29403
# [184]	validation-rmse:165.29403
# [185]	validation-rmse:165.29403
# [186]	validation-rmse:165.29403
# [187]	validation-rmse:165.29403
# [188]	validation-rmse:165.29403
# [189]	validation-rmse:165.29403
# [190]	validation-rmse:165.29403
# [191]	validation-rmse:165.29403
# [192]	validation-rmse:165.29403
# [193]	validation-rmse:165.29403
# [194]	validation-rmse:165.29403
# [195]	validation-rmse:165.29403
# [196]	validation-rmse:165.29403
# [197]	validation-rmse:165.29403
# [198]	validation-rmse:165.29403
# [199]	validation-rmse:165.29403
# [200]	validation-rmse:165.29403
# [201]	validation-rmse:165.29403
# [202]	validation-rmse:165.29403
# [203]	validation-rmse:165.29403
# [204]	validation-rmse:165.29403
# [205]	validation-rmse:165.29403
# [206]	validation-rmse:165.29403
# [207]	validation-rmse:165.29403
# [208]	validation-rmse:165.29403
# [209]	validation-rmse:165.29403
# [210]	validation-rmse:165.29403
# [211]	validation-rmse:165.29403
# [212]	validation-rmse:165.29403
# [213]	validation-rmse:165.29403
# [214]	validation-rmse:165.29403
# [215]	validation-rmse:165.29403
# [216]	validation-rmse:165.29403
# [217]	validation-rmse:165.29403
# [218]	validation-rmse:165.29403
# [219]	validation-rmse:165.29403
# [220]	validation-rmse:165.29403
# [221]	validation-rmse:165.29403
# [222]	validation-rmse:165.29403
# [223]	validation-rmse:165.29403
# [224]	validation-rmse:165.29403
# [225]	validation-rmse:165.29403
# [226]	validation-rmse:165.29403
# [227]	validation-rmse:165.29403
# [228]	validation-rmse:165.29403
# 100%|██████████| 50/50 [03:53<00:00,  4.66s/trial, best loss: 165.2931118838521]
